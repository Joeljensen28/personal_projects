# %%
import pandas as pd
import numpy as np

# %%
aps = pd.read_csv('apostles_clean.csv')

# %%
nums = aps.filter(items=aps.columns[4:])

nums['president'] = np.where(
    nums['president'] == 'No',
    0,
    1
)

# %%
#nums = nums.fillna(0)

for column in nums.columns:
    print(
        column, 
        ': ',
        nums[column].isna().sum()
    )
# Out:
# age_ordained :  0
# age_left :  8
# president :  0
# age_aps_1 :  1
# age_aps_2 :  1
# age_aps_3 :  3
# age_aps_4 :  3
# age_aps_5 :  5
# age_aps_6 :  5
# age_aps_7 :  5
# age_aps_8 :  5
# age_aps_9 :  9
# age_aps_10 :  10
# age_aps_11 :  11
# age_aps_12 :  12
# age_aps_13 :  13
# age_aps_14 :  14
# birth_year :  0
